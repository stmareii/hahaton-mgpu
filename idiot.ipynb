# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('data/hakaton.csv', sep=';')
df
# Out:
#           last_name first_name    middle_name       bdate gender  \
# 0             МУСЮС  АЛЕКСАНДР            NaN  2013-07-16      М
# 1           СОБОЛЕВ       ЮРИЙ    ГЕННАДЬЕВИЧ  2018-01-26      М
# 2             РЯБОВ   ГЕННАДИЙ      СЕРГЕЕВИЧ  2014-08-21      М
# 3           БОРИСОВ   АНАТОЛИЙ    НИКОЛЛАЕВИЧ  2018-07-22      М
# 4          КАРПЕВИЧ     ВИКТОР        ЮРЬЕВИЧ  2019-01-18      М
# ...             ...        ...            ...         ...    ...
# 25623       ЛАЗАРЕВ      ДЕНИС   ВЛАДИМИРОВИЧ  2015-06-28      М
# 25624       ВИДАКОВ     МИХАИЛ      СЕРГЕЕВИЧ  2018-03-06      М
# 25625  ТОЛОКОНУШКОВ    ЕВГЕНИЙ      ФЕДОРОВИЧ  2018-04-14      М
# 25626       ТИХОНОВ   ВЛАДИМИР  АЛЕКСАНДРОВИЧ  2017-09-11      М
# 25627       СОРОКИН    НИКОЛАЙ     НИКОЛАЕВИЧ  2010-01-23      М
#
#                id_doc guard_last_name guard_first_name guard_middle_name  \
# 0           240045105       АГАФОНОВА          КЛАВДИЯ               NaN
# ...

# %%
df.isna().sum()
# Out:
# last_name               0
# first_name              0
# middle_name          4469
# bdate                   0
# gender                  0
# id_doc                 33
# guard_last_name         0
# guard_first_name        0
# guard_middle_name    7389
# guard_bdate             0
# guard_gender            0
# guard_id_doc           76
# our_number              0
# ogrn_naprav             0
# name_naprav             0
# ogrn_area               0
# name_area               0
# variant                 0
# class                   0
# test_date               0
# result                  0
# dtype: int64

# %%
df.describe()
# Out:
#         ogrn_naprav     ogrn_area
# count  2.562800e+04  2.562800e+04
# mean   1.104995e+12  1.050151e+12
# std    2.044263e+12  5.329155e+10
# min    1.020101e+12  1.020101e+12
# 25%    1.024701e+12  1.025203e+12
# 50%    1.027102e+12  1.027403e+12
# 75%    1.035006e+12  1.035404e+12
# max    3.210571e+14  1.241600e+12

# %%
num_of_child_ids = len(df['id_doc'].unique())
num_of_child_ids
# Out:
# 21928

# %%
id_loc_num = df.groupby('id_doc').size().reset_index(name='count').sort_values('count',ascending=False)
id_loc_num
# Out:
#             id_doc  count
# 0                -     13
# 6470       0594160      9
# 13054    404331516      8
# 6844       0682253      8
# 13567    404832737      6
# ...            ...    ...
# 21911     №9870188      1
# 4      --406127589      1
# 3      --406034086      1
# 2      --404622851      1
# 1      --404577571      1
#
# [21927 rows x 2 columns]

# %%
id_neg = id_loc_num['id_doc'].str.isdigit().sum()
id_neg
# Out:
# np.int64(15382)

# %% [markdown]
# ## ПЕРЕЙДЕМ К АНАЛИТИКЕ ID ОПЕКУНА

# %%
num_of_guard_ids = len(df['guard_id_doc'].unique())
num_of_guard_ids
# Out:
# 18125

# %%
id_loc_num = df.groupby('guard_id_doc').size().reset_index(name='count').sort_values('count',ascending=False)
id_loc_num
# Out:
#       guard_id_doc  count
# 2485       0682318     60
# 15259  8522№608090     12
# 13406   6824328757     11
# 10174    405073438     11
# 13763   7514515713     10
# ...            ...    ...
# 18112    №N4545127      1
# 18113    №N4571564      1
# 18114    №N4588721      1
# 18115    №N4602165      1
# 18116    №N4631168      1
#
# [18124 rows x 2 columns]

# %%
id_incorrect = id_loc_num['guard_id_doc'].str.isdigit().sum()
id_neg
# Out:
# np.int64(15382)

# %% [markdown]
# ## 3.попробуем убрать
